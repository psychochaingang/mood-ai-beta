# %% [markdown]
# # VibeCheck APK Builder
#
# Run this notebook to build the Android APK. Click **Runtime → Run All** and wait ~20 minutes.

# %%
# Install system deps
# !apt update && apt install -y git zip unzip openjdk-17-jdk autoconf libtool pkg-config zlib1g-dev libncurses5-dev cmake libffi-dev libssl-dev python3-pip 2>&1 | tail -5

# %%
# Clone the repo
# !git clone https://github.com/psychochaingang/mood-ai-beta.git
# %cd mood-ai-beta

# %%
# Install buildozer
# !pip install buildozer cython 2>&1 | tail -3

# %%
# Build the APK
# %cd mood_ai_app_project
# !buildozer android debug 2>&1

# %%
# Download the APK
from google.colab import files
import glob, os
apk = glob.glob('bin/*.apk')
if apk:
    files.download(apk[0])
    print(f"APK ready: {apk[0]}")
else:
    print("APK not found - check logs above")
